# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../walking_data/MC_FP_data/Tachibana/FP_data//non_shoes/Tachibana_non_shoes_00.csv', index_col=0)

# %%
y = df['Fz1'][16800:16900]
plt.plot(range(len(y)), y)
print(len(y))
# Out:
# 100
